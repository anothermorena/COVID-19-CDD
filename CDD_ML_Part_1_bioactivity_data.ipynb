# %% [markdown]
# ## COVID-19: Computational Drug Discovery [Download Bioactivity Data][Part 1]
#
# This an attempt to find an FDA approved compound or molecule that will inhibit the function of Severe Acute Respiratory Syndrome Coronavirus 2 (SARS-CoV2).
#
# An Otsogile Onalepelo Project aka Morena!

# %% [markdown]
# ## ChEMBL Database
# The ChEMBL Database is a database that contains curated bioactivity data of more than 2 million compounds. It is the one used as the data source for this project

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## Search for Target protein
#
# Targets here refers to the proteins or the organisim that the drug will act on. Basically,the compound will come into contact with the target protein or organism and induce a modulatory activity on it. Either to activate the protein or inhibit it. For this project,I will be working with SARS-CoV2

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target: search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 7                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
# 7    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                   SARS coronavirus   15.0
# 2                                 Feline coronavirus   15.0
# 3                             Human coronavirus 229E   13.0
# 4                SARS coronavirus 3C-like proteinase   10.0
# 5  Middle East respiratory syndrome-related coron...    9.0
# 6                          Replicase polyprotein 1ab    4.0
# 7                          Replicase polyprotein 1ab    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612575
# 2               False     CHEMBL612744
# 3               False     CHEMBL613837
# 4               False       CHEMBL3927
# 5               False    CHEMBL4296578
# 6               False       CHEMBL5118
# 7               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM   227859
# 2                                                 []        ORGANISM    12663
# 3                                                 []        ORGANISM    11137
# 4  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   227859
# 5                                                 []        ORGANISM  1335626
# 6  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   227859
# 7  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %% [markdown]
# ## **Select and retrieve bioactivity data for *SARS Coronavirus 2 Replicase polyprotein 1ab* (seventh entry)**
#
# Replicase polyprotein 1ab is the protein responsible for replication and transcription of the viral RNA genome. We will assign the seventh entry (which corresponds to the target protein: *Replicase polyprotein 1ab*), to the ***selected_target*** variable

# %%
#Unique identification of the target
selected_target = targets.target_chembl_id[7]
selected_target
# Out:
# 'CHEMBL4523582'

# %% [markdown]
# Retrieve only bioactivity data for *Replicase polyprotein 1ab* (CHEMBL4523582) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0  Dtt Insensitive     19964199                  []   CHEMBL4495583
# 1  Dtt Insensitive     19964200                  []   CHEMBL4495583
# 2  Dtt Insensitive     19964201                  []   CHEMBL4495583
#
#                                    assay_description assay_type  \
# 0  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 1  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 2  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000019
# 1                    None                   None  BAO_0000190  BAO_0000019
# 2                    None                   None  BAO_0000190  BAO_0000019
#
#    ...                                  target_organism  \
# 0  ...  Severe acute respiratory syndrome coronavirus 2
# 1  ...  Severe acute respiratory syndrome coronavirus 2
# 2  ...  Severe acute respiratory syndrome coronavirus 2
#
#             target_pref_name target_tax_id text_value  toid  type  units  \
# 0  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 1  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 2  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
#
#      uo_units upper_value value
# 0  UO_0000065        None  0.39
# 1  UO_0000065        None  0.21
# 2  UO_0000065        None  0.08
#
# [3 rows x 45 columns]

# %% [markdown]
# lets see what other standard type values are present on the above df

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# For this dataset it would not matter if we just went ahead without filtering as it only has the ideal unit of measurement, but for other datasets this might not be the case it could ec50 or %activity combined with ic50 and you might have to filter such a dataset. This is just to standardized our dataset to avoid having a mixture of bioactivity units
#
# ## Data Exploration
# If any compounds has missing values for the **standard_value,canonical_smiles & molecule_chembl_id** columns, drop them. These are the features that will be extracted from this bioactivity data.
#
# Standard value  is the potency of the drug, the lower the number the better and vice versa.Ideally, we want the standard value to be as low as possible. This will mean the inhitory concentration at 50% will have a low concentration. Simply put, inorder to illicit 50% of the inhibition of a target protein you will need a low concentration of the drug. Think of the number as a representation of the drug. The lower the concentration that is required the better it is. If this number is high, it will mean you require more amounts of the drug in order to produce the same inhibition at 50%. For example, having to take 5ml of a medication instead of 5l for the same medication if the value is very high, which is impossible.
#
#
# Canonical smiles:  This is information about the chemical structure of that compound/molecule. A canonical smile is the exact atomic details of the molecule. A molecule or compund here means a drug. These are capable of producing a modulatory activity. In otherwords, it excerts some effect (inhibit or activate) the target protein. We are going to use canonical smiles as input to  calculate the molecular descriptors. Molecular descriptors distinguish one molecule from others.
#
# Molecule id: is self explanotory. Each compound is described by a chembl molecule ID.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   activity_comment           117 non-null    object
#  1   activity_id                117 non-null    int64
#  2   activity_properties        117 non-null    object
#  3   assay_chembl_id            117 non-null    object
#  4   assay_description          117 non-null    object
#  5   assay_type                 117 non-null    object
#  6   assay_variant_accession    0 non-null      object
#  7   assay_variant_mutation     0 non-null      object
#  8   bao_endpoint               117 non-null    object
#  9   bao_format                 117 non-null    object
#  10  bao_label                  117 non-null    object
#  11  canonical_smiles           110 non-null    object
#  12  data_validity_comment      0 non-null      object
#  13  data_validity_description  0 non-null      object
#  14  document_chembl_id         117 non-null    object
#  15  document_journal           0 non-null      object
#  16  document_year              117 non-null    int64
#  17  ligand_efficiency          0 non-null      object
#  18  molecule_chembl_id         117 non-null    object
#  19  molecule_pref_name         64 non-null     object
#  20  parent_molecule_chembl_id  117 non-null    object
#  21  pchembl_value              114 non-null    object
#  22  potential_duplicate        117 non-null    int64
#  23  qudt_units                 117 non-null    object
#  24  record_id                  117 non-null    int64
#  25  relation                   117 non-null    object
#  26  src_id                     117 non-null    int64
#  27  standard_flag              117 non-null    int64
#  28  standard_relation          117 non-null    object
#  29  standard_text_value        0 non-null      object
#  30  standard_type              117 non-null    object
#  31  standard_units             117 non-null    object
#  32  standard_upper_value       0 non-null      object
#  33  standard_value             117 non-null    object
#  34  target_chembl_id           117 non-null    object
#  35  target_organism            117 non-null    object
#  36  target_pref_name           117 non-null    object
#  37  target_tax_id              117 non-null    object
#  38  text_value                 0 non-null      object
#  39  toid                       0 non-null      object
#  40  type                       117 non-null    object
#  41  units                      117 non-null    object
#  42  uo_units                   117 non-null    object
#  43  upper_value                0 non-null      object
#  44  value                      117 non-null    object
# dtypes: int64(6), object(39)
# memory usage: 41.3+ KB

# %%
df.standard_value.notna()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 112    True
# 113    True
# 114    True
# 115    True
# 116    True
# Name: standard_value, Length: 117, dtype: bool

# %%
df.isna().sum()
# Out:
# activity_comment               0
# activity_id                    0
# activity_properties            0
# assay_chembl_id                0
# assay_description              0
# assay_type                     0
# assay_variant_accession      117
# assay_variant_mutation       117
# bao_endpoint                   0
# bao_format                     0
# bao_label                      0
# canonical_smiles               7
# data_validity_comment        117
# data_validity_description    117
# document_chembl_id             0
# document_journal             117
# document_year                  0
# ligand_efficiency            117
# molecule_chembl_id             0
# molecule_pref_name            53
# parent_molecule_chembl_id      0
# pchembl_value                  3
# potential_duplicate            0
# qudt_units                     0
# record_id                      0
# relation                       0
# src_id                         0
# standard_flag                  0
# standard_relation              0
# standard_text_value          117
# standard_type                  0
# standard_units                 0
# standard_upper_value         117
# standard_value                 0
# target_chembl_id               0
# target_organism                0
# target_pref_name               0
# target_tax_id                  0
# text_value                   117
# toid                         117
# type                           0
# units                          0
# uo_units                       0
# upper_value                  117
# value                          0
# dtype: int64

# %%
#export the data frame to view it as a spread sheet
df.to_csv('bioactivity_raw_data.csv', index=False)

# %%
df.describe()
# Out:
#         activity_id  document_year  potential_duplicate     record_id  src_id  \
# count  1.170000e+02          117.0                117.0  1.170000e+02   117.0
# mean   1.996426e+07         2020.0                  0.0  3.346515e+06    52.0
# std    3.391902e+01            0.0                  0.0  2.366436e+03     0.0
# min    1.996420e+07         2020.0                  0.0  3.341963e+06    52.0
# 25%    1.996423e+07         2020.0                  0.0  3.344721e+06    52.0
# 50%    1.996426e+07         2020.0                  0.0  3.346744e+06    52.0
# 75%    1.996429e+07         2020.0                  0.0  3.348347e+06    52.0
# max    1.996432e+07         2020.0                  0.0  3.350610e+06    52.0
#
#        standard_flag
# count          117.0
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %% [markdown]
# From the all above data exploration, some features do have missing values. Our dataset have two data types, int64 and objects. But since we do not need all the features for this project we are only going to drop missing values for canonical smiles, standard_value and chembl_id. These are the only features we need and drop the rest.
#
#
# ## Handling Missing Values

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0    Dtt Insensitive     19964199                  []   CHEMBL4495583
# 1    Dtt Insensitive     19964200                  []   CHEMBL4495583
# 2    Dtt Insensitive     19964201                  []   CHEMBL4495583
# 3    Dtt Insensitive     19964202                  []   CHEMBL4495583
# 4    Dtt Insensitive     19964203                  []   CHEMBL4495583
# ..               ...          ...                 ...             ...
# 112  Dtt Insensitive     19964311                  []   CHEMBL4495583
# 113  Dtt Insensitive     19964312                  []   CHEMBL4495583
# 114  Dtt Insensitive     19964313                  []   CHEMBL4495583
# 115  Dtt Insensitive     19964314                  []   CHEMBL4495583
# 116  Dtt Insensitive     19964315                  []   CHEMBL4495583
#
#                                      assay_description assay_type  \
# 0    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 1    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 2    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 3    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 4    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# ..                                                 ...        ...
# 112  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 113  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 114  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 115  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 116  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000019
# 1                      None                   None  BAO_0000190  BAO_0000019
# 2                      None                   None  BAO_0000190  BAO_0000019
# 3                      None                   None  BAO_0000190  BAO_0000019
# 4                      None                   None  BAO_0000190  BAO_0000019
# ..                      ...                    ...          ...          ...
# 112                    None                   None  BAO_0000190  BAO_0000019
# 113                    None                   None  BAO_0000190  BAO_0000019
# 114                    None                   None  BAO_0000190  BAO_0000019
# 115                    None                   None  BAO_0000190  BAO_0000019
# 116                    None                   None  BAO_0000190  BAO_0000019
#
#      ...                                  target_organism  \
# 0    ...  Severe acute respiratory syndrome coronavirus 2
# 1    ...  Severe acute respiratory syndrome coronavirus 2
# 2    ...  Severe acute respiratory syndrome coronavirus 2
# 3    ...  Severe acute respiratory syndrome coronavirus 2
# 4    ...  Severe acute respiratory syndrome coronavirus 2
# ..   ...                                              ...
# 112  ...  Severe acute respiratory syndrome coronavirus 2
# 113  ...  Severe acute respiratory syndrome coronavirus 2
# 114  ...  Severe acute respiratory syndrome coronavirus 2
# 115  ...  Severe acute respiratory syndrome coronavirus 2
# 116  ...  Severe acute respiratory syndrome coronavirus 2
#
#               target_pref_name target_tax_id text_value  toid  type  units  \
# 0    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 1    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 2    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 3    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 4    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# ..                         ...           ...        ...   ...   ...    ...
# 112  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 113  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 114  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 115  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 116  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
#
#        uo_units upper_value value
# 0    UO_0000065        None  0.39
# 1    UO_0000065        None  0.21
# 2    UO_0000065        None  0.08
# 3    UO_0000065        None  1.58
# 4    UO_0000065        None  0.04
# ..          ...         ...   ...
# 112  UO_0000065        None  1.24
# 113  UO_0000065        None  4.98
# 114  UO_0000065        None  0.75
# 115  UO_0000065        None  0.88
# 116  UO_0000065        None  1.93
#
# [117 rows x 45 columns]

# %%
df3 = df2[df2.canonical_smiles.notna()]
df3
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0    Dtt Insensitive     19964199                  []   CHEMBL4495583
# 1    Dtt Insensitive     19964200                  []   CHEMBL4495583
# 2    Dtt Insensitive     19964201                  []   CHEMBL4495583
# 3    Dtt Insensitive     19964202                  []   CHEMBL4495583
# 4    Dtt Insensitive     19964203                  []   CHEMBL4495583
# ..               ...          ...                 ...             ...
# 111  Dtt Insensitive     19964310                  []   CHEMBL4495583
# 112  Dtt Insensitive     19964311                  []   CHEMBL4495583
# 113  Dtt Insensitive     19964312                  []   CHEMBL4495583
# 114  Dtt Insensitive     19964313                  []   CHEMBL4495583
# 116  Dtt Insensitive     19964315                  []   CHEMBL4495583
#
#                                      assay_description assay_type  \
# 0    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 1    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 2    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 3    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 4    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# ..                                                 ...        ...
# 111  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 112  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 113  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 114  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 116  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000019
# 1                      None                   None  BAO_0000190  BAO_0000019
# 2                      None                   None  BAO_0000190  BAO_0000019
# 3                      None                   None  BAO_0000190  BAO_0000019
# 4                      None                   None  BAO_0000190  BAO_0000019
# ..                      ...                    ...          ...          ...
# 111                    None                   None  BAO_0000190  BAO_0000019
# 112                    None                   None  BAO_0000190  BAO_0000019
# 113                    None                   None  BAO_0000190  BAO_0000019
# 114                    None                   None  BAO_0000190  BAO_0000019
# 116                    None                   None  BAO_0000190  BAO_0000019
#
#      ...                                  target_organism  \
# 0    ...  Severe acute respiratory syndrome coronavirus 2
# 1    ...  Severe acute respiratory syndrome coronavirus 2
# 2    ...  Severe acute respiratory syndrome coronavirus 2
# 3    ...  Severe acute respiratory syndrome coronavirus 2
# 4    ...  Severe acute respiratory syndrome coronavirus 2
# ..   ...                                              ...
# 111  ...  Severe acute respiratory syndrome coronavirus 2
# 112  ...  Severe acute respiratory syndrome coronavirus 2
# 113  ...  Severe acute respiratory syndrome coronavirus 2
# 114  ...  Severe acute respiratory syndrome coronavirus 2
# 116  ...  Severe acute respiratory syndrome coronavirus 2
#
#               target_pref_name target_tax_id text_value  toid  type  units  \
# 0    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 1    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 2    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 3    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 4    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# ..                         ...           ...        ...   ...   ...    ...
# 111  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 112  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 113  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 114  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 116  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
#
#        uo_units upper_value value
# 0    UO_0000065        None  0.39
# 1    UO_0000065        None  0.21
# 2    UO_0000065        None  0.08
# 3    UO_0000065        None  1.58
# 4    UO_0000065        None  0.04
# ..          ...         ...   ...
# 111  UO_0000065        None  4.36
# 112  UO_0000065        None  1.24
# 113  UO_0000065        None  4.98
# 114  UO_0000065        None  0.75
# 116  UO_0000065        None  1.93
#
# [110 rows x 45 columns]

# %% [markdown]
# They were around 7 missing values for canonical smiles which were dropped from above dataframe

# %%
df4 = df3[df3.molecule_chembl_id.notna()]
df4
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0    Dtt Insensitive     19964199                  []   CHEMBL4495583
# 1    Dtt Insensitive     19964200                  []   CHEMBL4495583
# 2    Dtt Insensitive     19964201                  []   CHEMBL4495583
# 3    Dtt Insensitive     19964202                  []   CHEMBL4495583
# 4    Dtt Insensitive     19964203                  []   CHEMBL4495583
# ..               ...          ...                 ...             ...
# 111  Dtt Insensitive     19964310                  []   CHEMBL4495583
# 112  Dtt Insensitive     19964311                  []   CHEMBL4495583
# 113  Dtt Insensitive     19964312                  []   CHEMBL4495583
# 114  Dtt Insensitive     19964313                  []   CHEMBL4495583
# 116  Dtt Insensitive     19964315                  []   CHEMBL4495583
#
#                                      assay_description assay_type  \
# 0    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 1    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 2    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 3    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 4    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# ..                                                 ...        ...
# 111  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 112  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 113  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 114  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 116  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000019
# 1                      None                   None  BAO_0000190  BAO_0000019
# 2                      None                   None  BAO_0000190  BAO_0000019
# 3                      None                   None  BAO_0000190  BAO_0000019
# 4                      None                   None  BAO_0000190  BAO_0000019
# ..                      ...                    ...          ...          ...
# 111                    None                   None  BAO_0000190  BAO_0000019
# 112                    None                   None  BAO_0000190  BAO_0000019
# 113                    None                   None  BAO_0000190  BAO_0000019
# 114                    None                   None  BAO_0000190  BAO_0000019
# 116                    None                   None  BAO_0000190  BAO_0000019
#
#      ...                                  target_organism  \
# 0    ...  Severe acute respiratory syndrome coronavirus 2
# 1    ...  Severe acute respiratory syndrome coronavirus 2
# 2    ...  Severe acute respiratory syndrome coronavirus 2
# 3    ...  Severe acute respiratory syndrome coronavirus 2
# 4    ...  Severe acute respiratory syndrome coronavirus 2
# ..   ...                                              ...
# 111  ...  Severe acute respiratory syndrome coronavirus 2
# 112  ...  Severe acute respiratory syndrome coronavirus 2
# 113  ...  Severe acute respiratory syndrome coronavirus 2
# 114  ...  Severe acute respiratory syndrome coronavirus 2
# 116  ...  Severe acute respiratory syndrome coronavirus 2
#
#               target_pref_name target_tax_id text_value  toid  type  units  \
# 0    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 1    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 2    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 3    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 4    Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# ..                         ...           ...        ...   ...   ...    ...
# 111  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 112  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 113  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 114  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
# 116  Replicase polyprotein 1ab       2697049       None  None  IC50     uM
#
#        uo_units upper_value value
# 0    UO_0000065        None  0.39
# 1    UO_0000065        None  0.21
# 2    UO_0000065        None  0.08
# 3    UO_0000065        None  1.58
# 4    UO_0000065        None  0.04
# ..          ...         ...   ...
# 111  UO_0000065        None  4.36
# 112  UO_0000065        None  1.24
# 113  UO_0000065        None  4.98
# 114  UO_0000065        None  0.75
# 116  UO_0000065        None  1.93
#
# [110 rows x 45 columns]

# %% [markdown]
# ## Data pre-processing of the bioactivity data

# %% [markdown]
# ### Labeling compounds as either being active, inactive
# The bioactivity data is in the IC50 unit. IC50 is a quantitative measure that indicates how much of a particular inhibitory substance (e.g. drug) is needed to inhibit, in vitro, a given biological process or biological component by 50%.
#
# Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 1000 nM will be considered to be **inactive**.

# %%
bioactivity_class = []
for i in df4.standard_value:
  if float(i) >= 1000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")

# %% [markdown]
# ### Iterate the *molecule_chembl_id* to a list

# %%
mol_cid = []
for i in df4.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### Iterate *canonical_smiles* to a list

# %%
canonical_smiles = []
for i in df4.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### Iterate *standard_value* to a list

# %%
standard_value = []
for i in df4.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles,standard_value,bioactivity_class))
df5 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles','standard_value','bioactivity_class'])

# %%
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL480   Cc1c(OCC(F)(F)F)ccnc1C[S+]([O-])c1nc2ccccc2[nH]1
# 1         CHEMBL178459                              Cc1c(-c2cnccn2)ssc1=S
# 2        CHEMBL3545157            O=c1sn(-c2cccc3ccccc23)c(=O)n1Cc1ccccc1
# 3         CHEMBL297453  O=C(O[C@@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1cc(O)c(O)...
# 4        CHEMBL4303595                            O=C1C=Cc2cc(Br)ccc2C1=O
# ..                 ...                                                ...
# 105       CHEMBL376488  COc1nc2ccc(Br)cc2cc1[C@@H](c1ccccc1)[C@@](O)(C...
# 106       CHEMBL154580                             C=CC(=O)c1ccc2ccccc2c1
# 107       CHEMBL354349               C[n+]1c2cc(N)ccc2cc2ccc(N)cc21.[Cl-]
# 108      CHEMBL1382627             Nc1ccc(S(=O)(=O)[N-]c2ncccn2)cc1.[Ag+]
# 109      CHEMBL1977761  C[n+]1c2cc(N)ccc2cc2ccc(N)cc21.Cl.Nc1ccc2cc3cc...
#
#     standard_value bioactivity_class
# 0            390.0            active
# 1            210.0            active
# 2             80.0            active
# 3           1580.0          inactive
# 4             40.0            active
# ..             ...               ...
# 105         4360.0          inactive
# 106         1240.0          inactive
# 107         4980.0          inactive
# 108          750.0            active
# 109         1930.0          inactive
#
# [110 rows x 4 columns]

# %%
df5.bioactivity_class.unique()
# Out:
# array(['active', 'inactive'], dtype=object)

# %% [markdown]
# Lets save our data for part two.

# %%
df5.to_csv('bioactivity_preprocessed_data.csv', index=False)
